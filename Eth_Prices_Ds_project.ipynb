# %% [markdown]
# <a href="https://colab.research.google.com/github/krupalitrivedi/ETH-USD-Prices-Visualization/blob/master/Eth_Prices_Ds_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Eth Prices Analysis

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %% [markdown]
# ##Exploring Data

# %%
#importing data
df = pd.read_csv('/content/drive/My Drive/DPA/ETH-USD.csv')
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2017-11-09  308.644989  329.451996  307.056000  320.884003  320.884003
# 1  2017-11-10  320.670990  324.717987  294.541992  299.252991  299.252991
# 2  2017-11-11  298.585999  319.453003  298.191986  314.681000  314.681000
# 3  2017-11-12  314.690002  319.153015  298.513000  307.907990  307.907990
# 4  2017-11-13  307.024994  328.415009  307.024994  316.716003  316.716003
#
#        Volume
# 0   893249984
# 1   885985984
# 2   842300992
# 3  1613479936
# 4  1041889984

# %%
df.tail()
# Out:
#             Date         Open         High          Low        Close  \
# 1593  2022-03-21  2860.103271  2954.556641  2838.250488  2897.976563
# 1594  2022-03-22  2897.774170  3040.382813  2892.544434  2973.131104
# 1595  2022-03-23  2973.145020  3036.752197  2933.306641  3031.067139
# 1596  2022-03-24  3031.060791  3118.387695  3012.326660  3108.062012
# 1597  2022-03-25  3109.523438  3182.826660  3097.624268  3122.535889
#
#         Adj Close       Volume
# 1593  2897.976563  15206116098
# 1594  2973.131104  16830539230
# 1595  3031.067139  16008767658
# 1596  3108.062012  18070503166
# 1597  3122.535889  16882068480

# %% [markdown]
# ###Feature analysis

# %%
m,n=df.shape
print(f"No of samples are {m}")
print(f"No of features are {n}")
# Out:
# No of samples are 1598
# No of features are 7

# %%
df.columns.tolist()
# Out:
# ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']

# %% [markdown]
# ###Univariate and Bivariate non-graphical analysis

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1598.000000  1598.000000  1598.000000  1598.000000  1598.000000
# mean   1026.060794  1061.282123   986.461636  1027.554834  1027.554834
# std    1230.979724  1270.582395  1185.384747  1231.398723  1231.398723
# min      84.279694    85.342743    82.829887    84.308296    84.308296
# 25%     196.428421   201.416004   188.846440   196.605812   196.605812
# 50%     386.373398   396.498703   375.446228   386.445556   386.445556
# 75%    1647.892822  1721.577515  1568.554352  1659.367554  1659.367554
# max    4810.071289  4891.704590  4718.039063  4812.087402  4812.087402
#
#              Volume
# count  1.598000e+03
# mean   1.245347e+10
# std    1.121937e+10
# min    6.217330e+08
# 25%    3.154440e+09
# 50%    9.525409e+09
# 75%    1.764118e+10
# max    8.448291e+10

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1598 entries, 0 to 1597
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1598 non-null   object
#  1   Open       1598 non-null   float64
#  2   High       1598 non-null   float64
#  3   Low        1598 non-null   float64
#  4   Close      1598 non-null   float64
#  5   Adj Close  1598 non-null   float64
#  6   Volume     1598 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 87.5+ KB

# %%
df.max()
# Out:
# Date          2022-03-25
# Open         4810.071289
# High          4891.70459
# Low          4718.039063
# Close        4812.087402
# Adj Close    4812.087402
# Volume       84482912776
# dtype: object

# %%
df['Open'].argmax()
# Out:
# 1461

# %%
df['Close'].value_counts()
# Out:
# 320.884003     1
# 368.855927     1
# 377.441833     1
# 379.484039     1
# 381.190765     1
#               ..
# 171.447800     1
# 171.874664     1
# 170.046524     1
# 173.751266     1
# 3122.535889    1
# Name: Close, Length: 1598, dtype: int64

# %%
df.sort_values('High').head()
# Out:
#            Date       Open       High        Low      Close  Adj Close  \
# 401  2018-12-15  84.279694  85.342743  82.829887  84.440811  84.440811
# 400  2018-12-14  86.630356  87.144943  83.226479  84.308296  84.308296
# 402  2018-12-16  84.469406  87.568123  84.469406  85.262100  85.262100
# 399  2018-12-13  90.655228  91.111603  85.518311  86.539314  86.539314
# 398  2018-12-12  88.610703  92.240555  88.263557  90.593300  90.593300
#
#          Volume
# 401  1496176898
# 400  1651491877
# 402  1565817037
# 399  1754475622
# 398  1533050103

# %%
df[df['Low'] > 450].head()
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 16  2017-11-25  475.675995  485.191986  461.053009  466.276001  466.276001
# 17  2017-11-26  465.973999  472.722992  451.605988  471.329987  471.329987
# 18  2017-11-27  471.531006  493.404999  468.484985  480.355011  480.355011
# 19  2017-11-28  480.518005  482.480011  466.346985  472.902008  472.902008
# 23  2017-12-02  466.851013  476.239014  456.653015  463.449005  463.449005
#
#         Volume
# 16  1422080000
# 17  1197779968
# 18  1396480000
# 19  1346499968
# 23   943649984

# %%
df.groupby('High')['Close'].mean().head()
# Out:
# High
# 85.342743    84.440811
# 87.144943    84.308296
# 87.568123    85.262100
# 91.111603    86.539314
# 92.240555    90.593300
# Name: Close, dtype: float64

# %%
df[['Open', 'Close']].head()
# Out:
#          Open       Close
# 0  308.644989  320.884003
# 1  320.670990  299.252991
# 2  298.585999  314.681000
# 3  314.690002  307.907990
# 4  307.024994  316.716003

# %%
df.mean()
# Out:
# <ipython-input-17-c61f0c8f89b5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# Open         1.026061e+03
# High         1.061282e+03
# Low          9.864616e+02
# Close        1.027555e+03
# Adj Close    1.027555e+03
# Volume       1.245347e+10
# dtype: float64

# %%
df.mode().sum()
# Out:
# Date         2017-11-092017-11-102017-11-112017-11-122017-1...
# Open                                                205.173996
# High                                            1695928.832391
# Low                                             1576365.694915
# Close                                           1642032.625257
# Adj Close                                       1642032.625257
# Volume                                          19900638493052
# dtype: object

# %%
df.median()
# Out:
# <ipython-input-19-6d467abf240d>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# Open         3.863734e+02
# High         3.964987e+02
# Low          3.754462e+02
# Close        3.864456e+02
# Adj Close    3.864456e+02
# Volume       9.525409e+09
# dtype: float64

# %%
df.std()
# Out:
# <ipython-input-20-ce97bb7eaef8>:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.std()
# Open         1.230980e+03
# High         1.270582e+03
# Low          1.185385e+03
# Close        1.231399e+03
# Adj Close    1.231399e+03
# Volume       1.121937e+10
# dtype: float64

# %%
df.var()
# Out:
# <ipython-input-21-28ded241fd7c>:1: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.var()
# Open         1.515311e+06
# High         1.614380e+06
# Low          1.405137e+06
# Close        1.516343e+06
# Adj Close    1.516343e+06
# Volume       1.258743e+20
# dtype: float64

# %% [markdown]
# ##Data Cleaning

# %%
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df.isna().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %% [markdown]
# ##Exploratory Data Analysis of ETH prices using graphs

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# distribution of volume (in mn)
plt.figure(figsize=(12,4))
df.Volume.plot(kind='hist', bins=50)
plt.title('Volume')
plt.grid()
plt.show()

# %%
# plot price development
fig, ax = plt.subplots(figsize=(16,6))
df['Price'] = df['Adj Close']
ax.plot(df.Date, df.Price, marker='.')
ax.xaxis.set_major_locator(plt.MaxNLocator(12)) # reduce number of x-labels
plt.title('Price')
plt.grid()
plt.show()

# %%
#Some derived features

df['logPrice'] = np.log(df.Price)
df['logChange'] = df.logPrice.diff()
df['percChange'] = df.Price.pct_change()

# %%
fig, ax = plt.subplots(figsize=(16,6))
ax.scatter(df.Date, df.percChange, marker='.')
ax.xaxis.set_major_locator(plt.MaxNLocator(12)) # reduce number of x-labels
plt.title('Relative changes')
plt.grid()
plt.show()

# %%
# plot price vs volume (each in log scale)
plt.figure(figsize=(6,6))
plt.scatter(np.log(df.Volume), df.logPrice, alpha=0.2)
plt.title('log(Price) vs log(Volume)')
plt.xlabel('log(Volume)')
plt.ylabel('log(Price)')
plt.grid()
plt.show()

# %%
# extract time features
df.Date = pd.to_datetime(df.Date)
df['Year'] = df.Date.dt.year
df['Month'] = df.Date.dt.month
df['Day'] = df.Date.dt.day

# %%
# evaluate mean values by month
plt.figure(figsize=(12,4))
logC_month = df.groupby(by='Month')['logChange'].mean()
plt.plot(logC_month, marker='.')
plt.ylim(-0.05, 0.05)
plt.title('logChange - mean by month')
plt.grid()
plt.show()

# %%
#High prices vs low prices
import seaborn as sns
sns.lineplot(df['Low'],color='red')
sns.lineplot(df['High'],color='green')
plt.title('ETH High Vs Low')
plt.show()

# %%
#Visualizing the closing price
df['Close'].plot(kind='hist', bins=500);

# %%
high_prices = list(df["High"])
high_prices[:5]
# Out:
# [329.451996, 324.717987, 319.453003, 319.153015, 328.415009]

# %% [markdown]
# ##Statistical/Inferential Analysis
#
# Statistical analysis is the collection and interpretation of data in order to uncover patterns and trends.
# Different tests done are:
#
# - Ztest
# - Ttest
# - Correlation analysis

# %%
import random

random.seed(120) 
high_prices = list(df["High"])
high_prices_sample = random.sample(high_prices, k=3) 
print (high_prices_sample)
# Out:
# [366.432159, 142.189209, 119.423767]

# %%
from statsmodels.stats.weightstats import ztest
high_prices = list(df["High"])
low_prices = list(df["Low"])

ztest(high_prices, low_prices, value=0)
# Out:
# (1.7212351376837416, 0.08520816409025653)

# %%
import scipy.stats as stats
low_prices = list(df["Low"])

stats.ttest_1samp(low_prices, popmean=10)
# Out:
# TtestResult(statistic=32.92943189211358, pvalue=6.243650457507776e-182, df=1597)

# %%
import scipy.stats as stats
high_prices = list(df["High"])
low_prices = list(df["Low"])
corr = stats.pearsonr(high_prices, low_prices)
print (corr)
# Out:
# PearsonRResult(statistic=0.9981892874412835, pvalue=0.0)
